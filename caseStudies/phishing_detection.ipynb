# %%
import pandas as pd
import matplotlib.pyplot
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("dataset.csv")

# %%
#Ensure its read correctly.
df.head()
# Out:
#    index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 0      1                          -1              1                   1
# 1      2                           1              1                   1
# 2      3                           1              0                   1
# 3      4                           1              0                   1
# 4      5                           1              0                  -1
#
#    having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# 0                 1                        -1             -1
# 1                 1                         1             -1
# 2                 1                         1             -1
# 3                 1                         1             -1
# 4                 1                         1             -1
#
#    having_Sub_Domain  SSLfinal_State  Domain_registeration_length   ...    \
# 0                 -1              -1                           -1   ...
# ...

# %%
#don't need the index column..
df.drop(['index'], inplace=True, axis=1)

# %%
# Reference: 
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
x_train, x_test, y_train, y_test = train_test_split(df.loc[:, df.columns != "Result"], 
                                                    df['Result'], 
                                                    test_size=0.33, 
                                                    random_state=42)

# %%
clfs = [LogisticRegression(), BernoulliNB(), RandomForestClassifier(), AdaBoostClassifier(), MLPClassifier(), svm.SVC(), KNeighborsClassifier()]
title = ['LogisticRegression', 'BernoulliNB', 'RandomForestClassifier', 'AdaBoostClassifier','MLPClassifier', 'SVM Classifier', 'KNN']

for t,clf in zip(title, clfs):
    model = clf
    model.fit(x_train, y_train)
    pred = model.predict(x_test)
    print(t,"Performance\n=========================")
    print(model.classes_)
    print(confusion_matrix(y_test, pred))
    print("Accurracy:", accuracy_score(y_test, pred)) 
    print("")
# Out:
# LogisticRegression Performance
# ...
# [-1  1]
# [[1423  142]
#  [ 140 1944]]
# Accurracy: 0.922718553028
#
# BernoulliNB Performance
# ...
# [-1  1]
# [[1400  165]
#  [ 193 1891]]
# Accurracy: 0.901890929022
#
# RandomForestClassifier Performance
# ...
# [-1  1]
# [[1482   83]
#  [  45 2039]]
# Accurracy: 0.96492189641
#
# AdaBoostClassifier Performance
# ...
# [-1  1]
# [[1447  118]
#  [ 103 1981]]
# Accurracy: 0.93943546177
#
# MLPClassifier Performance
# ...
# [-1  1]
# [[1461  104]
#  [  89 1995]]
# Accurracy: 0.947108796931
#
# SVM Classifier Performance
# ...
# [-1  1]
# [[1445  120]
#  [  95 1989]]
# Accurracy: 0.941079747876
#
# KNN Performance
# ...
# [-1  1]
# [[1436  129]
#  [ 117 1967]]
# Accurracy: 0.932584269663
