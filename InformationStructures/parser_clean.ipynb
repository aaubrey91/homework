# %%
#file = open("../../NightSix/obs.txt", "r")
file = open("../../NightSix/reg.txt", "r")
obs = [line for line in file]
file.close()

# %%
json_dict = dict()

for i, line in enumerate(obs):
    #msh = line.split("|")[0]
    
    #Key for the message header will be the line number (i) \. the first field in the row
    #if less than 10, add padding so it can be sorted correctly
    if i < 10:
        msh = "0"+str(i) + "." + line.split("|")[0]
    else:
        msh = str(i) + "." + line.split("|")[0]
    #msh = str(i) + "." + line.split("|")[0]
    json_dict[msh] = {}
    line = line.replace("\n", "")
    
    for ii, field in enumerate(line.split("|")):
        #construct key with MESSAGE HEADER.i.ii
        #key = line.split("|")[0]+"."+str(i)+"."+str(ii)
        #key = line.split("|")[0]+"."+str(ii)
        key = msh+"."+str(ii)
        
        
        # don't want the field if it is null
        if len(field)==0 or field=="":
            continue
        
        #dictionaries with nested keys/values need to be initialized before we can use them
        json_dict[msh][key] = {}
        
        for iii, segment in enumerate(field.split("^")):
            #Construct a segment key with our previous key with an additional numeric value
            key_segment = key+"."+str(iii)
            
            #don't want the field if it is null
            if len(segment)==0 or segment=="":
                continue
            
            #dictionaries with nested keys/values need to be initialized before we can use them
            json_dict[msh][key][key_segment] = {}
            
            for iiii, component in enumerate(segment.split("~")):
                #construct a key for our compoments
                key_component = key_segment+"."+str(iiii)
                
                """ inject the values by assigning the most inner values first then going outwards """
                
                #only need to assign the inner dictionary value if it exists 
                #(if we split on the delimiter and more than one value exists)
                if len(segment.split("~")) > 1: 
                    
                    #don't want the field if it is null
                    if len(component)==0 or component=="":
                        continue
                    json_dict[msh][key][key_segment][key_component] = component
                elif len(field.split("^")) > 1:
                    
                     #don't want the field if it is null
                    if len(segment)==0 or segment=="":
                        continue
                    json_dict[msh][key][key_segment] = segment
                else:
                    
                     #don't want the field if it is null
                    if len(segment)==0 or segment=="":
                        continue
                    json_dict[msh][key] = field

# %%
from collections import OrderedDict
json_dict["QRF"] = OrderedDict(json_dict["QRF"])
json_dict["QRF"]
# Out:
# OrderedDict([('QRF.3.0', 'QRF'),
#              ('QRF.3.1', 'MR0000'),
#              ('QRF.3.5',
#               {'QRF.3.5.0': {'QRF.3.5.0.0': '256946789',
#                 'QRF.3.5.0.1': '20100607',
#                 'QRF.3.5.0.2': 'MA',
#                 'QRF.3.5.0.3': 'MA99999999',
#                 'QRF.3.5.0.4': '88888888',
#                 'QRF.3.5.0.5': 'Martins'},
#                'QRF.3.5.1': 'Natalie',
#                'QRF.3.5.2': {'QRF.3.5.2.0': 'Lynn',
#                 'QRF.3.5.2.1': 'Randle',
#                 'QRF.3.5.2.2': '4466725',
#                 'QRF.3.5.2.3': 'Martins'},
#                'QRF.3.5.3': 'Jim',
#                'QRF.3.5.4': {'QRF.3.5.4.0': 'Christopher',
#                 'QRF.3.5.4.1': '446618'}})])

# %%
from collections import OrderedDict
def reorderDictItems(my_dictionary):
    return OrderedDict(my_dictionary)

# %%
#dictionaries aren't ordered. Reorder the keys
for key in json_dict.keys():
    json_dict[key] = reorderDictItems(json_dict[key])
    for inner_key in json_dict[key].keys():
        #print(key, inner_key)
        if type(json_dict[key][inner_key])==dict:
            json_dict[key][inner_key] = reorderDictItems(json_dict[key][inner_key])

# %%
json_dict["3.QRF"]["3.QRF.5"]
# Out:
# OrderedDict([('3.QRF.5.0',
#               {'3.QRF.5.0.0': '256946789',
#                '3.QRF.5.0.1': '20100607',
#                '3.QRF.5.0.2': 'MA',
#                '3.QRF.5.0.3': 'MA99999999',
#                '3.QRF.5.0.4': '88888888',
#                '3.QRF.5.0.5': 'Martins'}),
#              ('3.QRF.5.1', 'Natalie'),
#              ('3.QRF.5.2',
#               {'3.QRF.5.2.0': 'Lynn',
#                '3.QRF.5.2.1': 'Randle',
#                '3.QRF.5.2.2': '4466725',
#                '3.QRF.5.2.3': 'Martins'}),
#              ('3.QRF.5.3', 'Jim'),
#              ('3.QRF.5.4',
#               {'3.QRF.5.4.0': 'Christopher', '3.QRF.5.4.1': '446618'})])

# %%
import json
def write_json(my_dictionary, outfile):
    my_json = json.dumps(my_dictionary)
    file = open(outfile, "w")
    file.write(my_json)
    file.close()

# %%
write_json(json_dict, "my_json.json")

# %%
json_dict
# Out:
# {'00.MSH': OrderedDict([('00.MSH.0', 'MSH'),
#               ('00.MSH.1',
#                OrderedDict([('00.MSH.1.1', {'00.MSH.1.1.1': '\\&'})])),
#               ('00.MSH.2', 'HL7Soup'),
#               ('00.MSH.3', 'Instance1'),
#               ('00.MSH.4', 'HL7Soup'),
#               ('00.MSH.5', 'Instance2'),
#               ('00.MSH.6', '201005221610'),
#               ('00.MSH.8',
#                OrderedDict([('00.MSH.8.0', 'VXR'), ('00.MSH.8.1', 'V03')])),
#               ('00.MSH.9', '20100522MA53'),
#               ('00.MSH.10', 'T'),
#               ('00.MSH.11', '2.5.1'),
#               ('00.MSH.14', 'AL')]),
#  '01.MSA': OrderedDict([('01.MSA.0', 'MSA'),
#               ('01.MSA.1', 'AA'),
#               ('01.MSA.2', '20100522GA40')]),
#  '02.QRD': OrderedDict([('02.QRD.0', 'QRD'),
#               ('02.QRD.1', '201405221605'),
#               ('02.QRD.2', 'R'),
#               ('02.QRD.3', 'I'),
#               ('02.QRD.4', '20100522GA05'),
#               ('02.QRD.7',
#                OrderedDict([('02.QRD.7.0', '30'), ('02.QRD.7.1', 'RD')])),
#               ('02.QRD.8',
#                OrderedDict([('02.QRD.8.0', '3245'),
#                             ('02.QRD.8.1', 'Martins'),
#                             ('02.QRD.8.2', 'Jim'),
#                             ('02.QRD.8.3', 'Christoper')])),
#               ('02.QRD.9', 'VXI'),
#               ('02.QRD.10', OrderedDict([('02.QRD.10.1', 'MSIPP')]))]),
#  '03.QRF': OrderedDict([('03.QRF.0', 'QRF'),
#               ('03.QRF.1', 'MR0000'),
#               ('03.QRF.5',
#                OrderedDict([('03.QRF.5.0',
#                              {'03.QRF.5.0.0': '256946789',
#                               '03.QRF.5.0.1': '20100607',
#                               '03.QRF.5.0.2': 'MA',
#                               '03.QRF.5.0.3': 'MA99999999',
#                               '03.QRF.5.0.4': '88888888',
#                               '03.QRF.5.0.5': 'Martins'}),
#                             ('03.QRF.5.1', 'Natalie'),
#                             ('03.QRF.5.2',
#                              {'03.QRF.5.2.0': 'Lynn',
#                               '03.QRF.5.2.1': 'Randle',
#                               '03.QRF.5.2.2': '4466725',
#                               '03.QRF.5.2.3': 'Martins'}),
#                             ('03.QRF.5.3', 'Jim'),
#                             ('03.QRF.5.4',
#                              {'03.QRF.5.4.0': 'Christopher',
#                               '03.QRF.5.4.1': '446618'})]))]),
#  '04.PID': OrderedDict([('04.PID.0', 'PID'),
#               ('04.PID.2', '87687'),
#               ('04.PID.3',
#                OrderedDict([('04.PID.3.0', '1234'),
#                             ('04.PID.3.4', 'SR'),
#                             ('04.PID.3.5', {'04.PID.3.5.1': '1234-12'}),
#                             ('04.PID.3.9', 'LR'),
#                             ('04.PID.3.10', {'04.PID.3.10.1': '3872'}),
#                             ('04.PID.3.14',
#                              {'04.PID.3.14.0': 'MR',
#                               '04.PID.3.14.1': '221323671'}),
#                             ('04.PID.3.18', 'SS'),
#                             ('04.PID.3.19', {'04.PID.3.19.1': '430078856'}),
#                             ('04.PID.3.23', 'MA'),
#                             ('04.PID.3.24', ' ')])),
#               ('04.PID.5',
#                OrderedDict([('04.PID.5.0', 'Martins'),
#                             ('04.PID.5.1', 'Jim'),
#                             ('04.PID.5.2', 'Christopher'),
#                             ('04.PID.5.6', 'L')])),
#               ('04.PID.6',
#                OrderedDict([('04.PID.6.0', 'Randle'), ('04.PID.6.6', 'M')])),
#               ('04.PID.7', '20100607'),
#               ('04.PID.8', 'M'),
#               ('04.PID.9',
#                OrderedDict([('04.PID.9.0', 'Martins'),
#                             ('04.PID.9.1', 'BABY BOY'),
#                             ('04.PID.9.7', ' B')])),
#               ('04.PID.10',
#                OrderedDict([('04.PID.10.0', 'W'),
#                             ('04.PID.10.1', 'WHITE'),
#                             ('04.PID.10.2', 'NY8 RACE CODES'),
#                             ('04.PID.10.3', 'W'),
#                             ('04.PID.10.4', 'WHITE'),
#                             ('04.PID.10.5', 'HL70005')])),
#               ('04.PID.11',
#                OrderedDict([('04.PID.11.0', '123 HIgh St'),
#                             ('04.PID.11.1', 'APT 3B'),
#                             ('04.PID.11.2', 'London'),
#                             ('04.PID.11.3', 'London'),
#                             ('04.PID.11.4', 'EY2 5EE'),
#                             ('04.PID.11.5', ' '),
#                             ('04.PID.11.6', 'M'),
#                             ('04.PID.11.7', 'MSA CODE'),
#                             ('04.PID.11.8',
#                              {'04.PID.11.8.0': 'MA034',
#                               '04.PID.11.8.1': '345 ELM ST'}),
#                             ('04.PID.11.10', 'London'),
#                             ('04.PID.11.11', 'London'),
#                             ('04.PID.11.12', 'NH3 7TY'),
#                             ('04.PID.11.14', {'04.PID.11.14.0': 'Building'}),
#                             ('04.PID.11.20', 'BR'),
#                             ('04.PID.11.22', 'MA002')])),
#               ('04.PID.12', ' '),
#               ('04.PID.13',
#                OrderedDict([('04.PID.13.0', '(617) 555-1212 '),
#                             ('04.PID.13.1', 'PRN'),
#                             ('04.PID.13.2', 'PH'),
#                             ('04.PID.13.5', '617'),
#                             ('04.PID.13.6', '5551212')])),
#               ('04.PID.15',
#                OrderedDict([('04.PID.15.0', 'EN'),
#                             ('04.PID.15.1', 'ENGLISH'),
#                             ('04.PID.15.2', 'HL70296')])),
#               ('04.PID.23', 'CHILDRENS HOSPITAL')]),
#  '05.PD1': OrderedDict([('05.PD1.0', 'PD1'),
#               ('05.PD1.3',
#                OrderedDict([('05.PD1.3.0', 'CHILDREN=S HOSPITAL'),
#                             ('05.PD1.3.1', 'L'),
#                             ('05.PD1.3.2', '1234'),
#                             ('05.PD1.3.6',
#                              {'05.PD1.3.6.0': 'XX',
#                               '05.PD1.3.6.1': 'LEXINGTON CLINIC'}),
#                             ('05.PD1.3.8', '1234A'),
#                             ('05.PD1.3.12', 'FI ')])),
#               ('05.PD1.4',
#                OrderedDict([('05.PD1.4.0', '12345'),
#                             ('05.PD1.4.1', 'CARE'),
#                             ('05.PD1.4.2', ' PRIMARY'),
#                             ('05.PD1.4.5', 'DR'),
#                             ('05.PD1.4.6', 'MD'),
#                             ('05.PD1.4.9', 'L'),
#                             ('05.PD1.4.12', 'DN')])),
#               ('05.PD1.11',
#                OrderedDict([('05.PD1.11.0', '03'),
#                             ('05.PD1.11.1', 'REMINDER/RECALL - NO CALLS'),
#                             ('05.PD1.11.2', 'HL70215')])),
#               ('05.PD1.12', 'Y'),
#               ('05.PD1.13', 'A'),
#               ('05.PD1.14', '20100607')]),
#  '06.NK1': OrderedDict([('06.NK1.0', 'NK1'),
#               ('06.NK1.1', '1'),
#               ('06.NK1.2',
#                OrderedDict([('06.NK1.2.0', 'Martins'),
#                             ('06.NK1.2.1', 'Natalie'),
#                             ('06.NK1.2.2', 'Lynn')])),
#               ('06.NK1.3',
#                OrderedDict([('06.NK1.3.0', '32'),
#                             ('06.NK1.3.1', 'MOTHER'),
#                             ('06.NK1.3.2', 'HL70063')])),
#               ('06.NK1.33',
#                OrderedDict([('06.NK1.33.0', '898666725'),
#                             ('06.NK1.33.4', 'SS')]))]),
#  '07.NK1': OrderedDict([('07.NK1.0', 'NK1'),
#               ('07.NK1.1', '2'),
#               ('07.NK1.2',
#                OrderedDict([('07.NK1.2.0', 'Martins'),
#                             ('07.NK1.2.1', 'John'),
#                             ('07.NK1.2.2', 'Andrew')])),
#               ('07.NK1.3',
#                OrderedDict([('07.NK1.3.0', '33'),
#                             ('07.NK1.3.1', 'FATHER'),
#                             ('07.NK1.3.2', 'HL70063')])),
#               ('07.NK1.33',
#                OrderedDict([('07.NK1.33.0', '822546618'),
#                             ('07.NK1.33.4', 'SS')]))]),
#  '08.PV1': OrderedDict([('08.PV1.0', 'PV1'),
#               ('08.PV1.2', 'R'),
#               ('08.PV1.20',
#                OrderedDict([('08.PV1.20.0', 'V02'),
#                             ('08.PV1.20.1',
#                              {'08.PV1.20.1.0': '20100607',
#                               '08.PV1.20.1.1': 'H02'}),
#                             ('08.PV1.20.2', '20100607')]))]),
#  '09.RXA': OrderedDict([('09.RXA.0', 'RXA'),
#               ('09.RXA.1', '0'),
#               ('09.RXA.2', '1'),
#               ('09.RXA.3', '20100607'),
#               ('09.RXA.4', '20100607'),
#               ('09.RXA.5',
#                OrderedDict([('09.RXA.5.0', '08'),
#                             ('09.RXA.5.1', 'HEPB-PEDIATRIC/ADOLESCENT'),
#                             ('09.RXA.5.2', 'CVX'),
#                             ('09.RXA.5.3', '907744'),
#                             ('09.RXA.5.4', 'HEPB-PEDATRIC /ADOLESCENT'),
#                             ('09.RXA.5.5', 'CPT')])),
#               ('09.RXA.6', '.5'),
#               ('09.RXA.7',
#                OrderedDict([('09.RXA.7.0', 'ML'), ('09.RXA.7.2', 'ISO+')])),
#               ('09.RXA.9',
#                OrderedDict([('09.RXA.9.0', '03'),
#                             ('09.RXA.9.1',
#                              'HISTORICAL INFORMATION - FROM PARENT=S WRITTEN RECORD'),
#                             ('09.RXA.9.2', 'NIP0001')])),
#               ('09.RXA.10',
#                OrderedDict([('09.RXA.10.1', 'JONES'),
#                             ('09.RXA.10.2', 'LISA')])),
#               ('09.RXA.11',
#                OrderedDict([('09.RXA.11.3', 'CHILDREN=S HOSPITAL')])),
#               ('09.RXA.13', '5'),
#               ('09.RXA.14',
#                OrderedDict([('09.RXA.14.0', 'MCG'), ('09.RXA.14.2', 'ISO+')])),
#               ('09.RXA.15', 'MRK12345'),
#               ('09.RXA.16', '20100611'),
#               ('09.RXA.17',
#                OrderedDict([('09.RXA.17.0', 'MSD '),
#                             ('09.RXA.17.1', 'MERCK'),
#                             ('09.RXA.17.2', 'MVX')]))]),
#  '10.RXA': OrderedDict([('10.RXA.0', 'RXA'),
#               ('10.RXA.1', '0'),
#               ('10.RXA.2', '0'),
#               ('10.RXA.3', '20101207'),
#               ('10.RXA.4', '20101207'),
#               ('10.RXA.5',
#                OrderedDict([('10.RXA.5.0', '20'),
#                             ('10.RXA.5.1', 'TTP'),
#                             ('10.RXA.5.2', 'CVX')])),
#               ('10.RXA.6', '.5'),
#               ('10.RXA.7',
#                OrderedDict([('10.RXA.7.0', 'ML'), ('10.RXA.7.2', 'ISO+')])),
#               ('10.RXA.10',
#                OrderedDict([('10.RXA.10.0', '1234567891'),
#                             ('10.RXA.10.1', 'O=BRIAN'),
#                             ('10.RXA.10.2', 'ROBERT'),
#                             ('10.RXA.10.3', 'A'),
#                             ('10.RXA.10.5', 'DR'),
#                             ('10.RXA.10.6', ' MD')])),
#               ('10.RXA.11',
#                OrderedDict([('10.RXA.11.3', 'CHILD HEALTHCARE CLINIC'),
#                             ('10.RXA.11.8', '101 MAIN STREET'),
#                             ('10.RXA.11.10', 'London'),
#                             ('10.RXA.11.11', 'London')])),
#               ('10.RXA.15', 'W22532806'),
#               ('10.RXA.16', ' 20101230'),
#               ('10.RXA.17',
#                OrderedDict([('10.RXA.17.0', ' PMC'),
#                             ('10.RXA.17.1', ' PASTEUR MERIEUX CONNAUGHT'),
#                             ('10.RXA.17.2', 'MVX')])),
#               ('10.RXA.18',
#                OrderedDict([('10.RXA.18.0', '00'),
#                             ('10.RXA.18.1', 'PARENTAL DECISION'),
#                             ('10.RXA.18.2', 'NIP002')])),
#               ('10.RXA.20', 'RE')]),
#  '11.RXA': OrderedDict([('11.RXA.0', 'RXA'),
#               ('11.RXA.1', '0'),
#               ('11.RXA.2', '1'),
#               ('11.RXA.3', '20100907'),
#               ('11.RXA.4', '20100907'),
#               ('11.RXA.5',
#                OrderedDict([('11.RXA.5.0', '50'),
#                             ('11.RXA.5.1', 'DTAP-HIB'),
#                             ('11.RXA.5.2', 'CVX'),
#                             ('11.RXA.5.3', '90721'),
#                             ('11.RXA.5.4', 'DTAP-HIB'),
#                             ('11.RXA.5.5', 'CPT')])),
#               ('11.RXA.6', '.5'),
#               ('11.RXA.7',
#                OrderedDict([('11.RXA.7.0', 'ML'), ('11.RXA.7.2', 'ISO+')])),
#               ('11.RXA.9',
#                OrderedDict([('11.RXA.9.0', '00'),
#                             ('11.RXA.9.1', 'NEW IMMUNIZATION RECORD'),
#                             ('11.RXA.9.2', 'NIP001')])),
#               ('11.RXA.10',
#                OrderedDict([('11.RXA.10.0', '1234567890'),
#                             ('11.RXA.10.1', 'SMITH'),
#                             ('11.RXA.10.2', 'SALLY'),
#                             ('11.RXA.10.3', 'S'),
#                             ('11.RXA.10.12',
#                              {'11.RXA.10.12.0': 'VEI',
#                               '11.RXA.10.12.1': ' 1234567891'}),
#                             ('11.RXA.10.13', 'O=BRIAN'),
#                             ('11.RXA.10.14', 'ROBERT'),
#                             ('11.RXA.10.15', 'A'),
#                             ('11.RXA.10.17', 'DR'),
#                             ('11.RXA.10.18', 'MD'),
#                             ('11.RXA.10.24', 'OEI')])),
#               ('11.RXA.11',
#                OrderedDict([('11.RXA.11.3', 'CHILD HEALTHCARE CLINIC'),
#                             ('11.RXA.11.8', '101 MAIN STREET'),
#                             ('11.RXA.11.10', 'BOSTON'),
#                             ('11.RXA.11.11', 'MA ')])),
#               ('11.RXA.15', 'W46932777'),
#               ('11.RXA.16', ' 201008'),
#               ('11.RXA.17',
#                OrderedDict([('11.RXA.17.0', 'PMC'),
#                             ('11.RXA.17.1', 'PASTEUR MERIEUX CONNAUGHT'),
#                             ('11.RXA.17.2', 'MVX')])),
#               ('11.RXA.20', 'CP'),
#               ('11.RXA.21', 'A'),
#               ('11.RXA.22', ' 20110907120030')]),
#  '12.RXR': OrderedDict([('12.RXR.0', 'RXR'),
#               ('12.RXR.1',
#                OrderedDict([('12.RXR.1.0', 'IM'),
#                             ('12.RXR.1.1', 'INTRAMUSCULAR'),
#                             ('12.RXR.1.2', 'HL70162')])),
#               ('12.RXR.2',
#                OrderedDict([('12.RXR.2.0', 'LA'),
#                             ('12.RXR.2.1', 'LEFT ARM'),
#                             ('12.RXR.2.2', 'HL70163')]))]),
#  '13.OBX': OrderedDict([('13.OBX.0', 'OBX'),
#               ('13.OBX.1', '1'),
#               ('13.OBX.2', 'NM'),
#               ('13.OBX.3',
#                OrderedDict([('13.OBX.3.0', '60000-7'),
#                             ('13.OBX.3.1',
#                              'DTAP DOSE COUNT IN COMBINATION VACCINE'),
#                             ('13.OBX.3.2', 'LN')])),
#               ('13.OBX.5', '4'),
#               ('13.OBX.11', 'F')]),
#  '14.OBX': OrderedDict([('14.OBX.0', 'OBX'),
#               ('14.OBX.1', '2'),
#               ('14.OBX.2', 'NM'),
#               ('14.OBX.3',
#                OrderedDict([('14.OBX.3.0', '60002-3'),
#                             ('14.OBX.3.1',
#                              'HIB DOSE COUNT IN COMBINATION VACCINE'),
#                             ('14.OBX.3.2', 'LN')])),
#               ('14.OBX.5', '4'),
#               ('14.OBX.11', 'F')]),
#  '15.RXA': OrderedDict([('15.RXA.0', 'RXA'),
#               ('15.RXA.1', '0'),
#               ('15.RXA.2', '1'),
#               ('15.RXA.3', '20110907'),
#               ('15.RXA.4', '20110907'),
#               ('15.RXA.5',
#                OrderedDict([('15.RXA.5.0', '03'),
#                             ('15.RXA.5.1', 'MMR'),
#                             ('15.RXA.5.2', 'CVX')])),
#               ('15.RXA.6', '.5'),
#               ('15.RXA.7',
#                OrderedDict([('15.RXA.7.0', 'ML'), ('15.RXA.7.2', 'ISO+')])),
#               ('15.RXA.10',
#                OrderedDict([('15.RXA.10.0', '1234567890'),
#                             ('15.RXA.10.1', 'SMITH'),
#                             ('15.RXA.10.2', 'SALLY'),
#                             ('15.RXA.10.3', 'S'),
#                             ('15.RXA.10.12',
#                              {'15.RXA.10.12.0': 'VEI',
#                               '15.RXA.10.12.1': '1234567891'}),
#                             ('15.RXA.10.13', 'O=BRIAN'),
#                             ('15.RXA.10.14', 'ROBERT'),
#                             ('15.RXA.10.15', 'A'),
#                             ('15.RXA.10.17', 'DR'),
#                             ('15.RXA.10.18', 'MD'),
#                             ('15.RXA.10.24', 'OEI')])),
#               ('15.RXA.11',
#                OrderedDict([('15.RXA.11.3', 'CHILD HEALTHCARE CLINIC'),
#                             ('15.RXA.11.8', '101 MAIN STREET'),
#                             ('15.RXA.11.10', 'BOSTON'),
#                             ('15.RXA.11.11', 'MA')])),
#               ('15.RXA.15', 'W2348796456'),
#               ('15.RXA.16', '20120731'),
#               ('15.RXA.17',
#                OrderedDict([('15.RXA.17.0', 'MSD'),
#                             ('15.RXA.17.1', 'MERCK'),
#                             ('15.RXA.17.2', 'MVX')]))]),
#  '16.RXR': OrderedDict([('16.RXR.0', 'RXR'),
#               ('16.RXR.1',
#                OrderedDict([('16.RXR.1.0', 'SC'),
#                             ('16.RXR.1.1', 'SUBCUTANEOUS'),
#                             ('16.RXR.1.2', 'HL70162')])),
#               ('16.RXR.2',
#                OrderedDict([('16.RXR.2.0', 'LA'),
#                             ('16.RXR.2.1', 'LEFT ARM'),
#                             ('16.RXR.2.2', 'HL70163')]))]),
#  '17.RXA': OrderedDict([('17.RXA.0', 'RXA'),
#               ('17.RXA.1', '0'),
#               ('17.RXA.2', '5'),
#               ('17.RXA.3', '20140520'),
#               ('17.RXA.4', '20140520'),
#               ('17.RXA.5',
#                OrderedDict([('17.RXA.5.0', '20'),
#                             ('17.RXA.5.1', 'DTAP'),
#                             ('17.RXA.5.2', 'CVX')])),
#               ('17.RXA.6', '.5'),
#               ('17.RXA.7',
#                OrderedDict([('17.RXA.7.0', 'ML'), ('17.RXA.7.2', 'ISO+')])),
#               ('17.RXA.10',
#                OrderedDict([('17.RXA.10.0', '1234567891'),
#                             ('17.RXA.10.1', 'O=BRIAN'),
#                             ('17.RXA.10.2', 'ROBERT'),
#                             ('17.RXA.10.3', 'A'),
#                             ('17.RXA.10.5', 'DR'),
#                             ('17.RXA.10.6', 'MD')])),
#               ('17.RXA.11',
#                OrderedDict([('17.RXA.11.3', 'CHILD HEALTHCARE CLINIC'),
#                             ('17.RXA.11.8', '101 MAIN STREET'),
#                             ('17.RXA.11.10', 'BOSTON'),
#                             ('17.RXA.11.11', 'MA')])),
#               ('17.RXA.15', 'W22532806'),
#               ('17.RXA.16', '20140705'),
#               ('17.RXA.17',
#                OrderedDict([('17.RXA.17.0', ' PMC'),
#                             ('17.RXA.17.1', 'PASTEUR MERIEUX CONNAUGHT'),
#                             ('17.RXA.17.2', 'MVX')]))]),
#  '18.RXR': OrderedDict([('18.RXR.0', 'RXR'),
#               ('18.RXR.1',
#                OrderedDict([('18.RXR.1.0', 'IM'),
#                             ('18.RXR.1.1', 'INTRAMUSCULAR'),
#                             ('18.RXR.1.2', 'HL70162')])),
#               ('18.RXR.2',
#                OrderedDict([('18.RXR.2.0', 'LA'),
#                             ('18.RXR.2.1', 'LEFT ARM'),
#                             ('18.RXR.2.2', 'HL70163')]))]),
#  '19.RXA': OrderedDict([('19.RXA.0', 'RXA'),
#               ('19.RXA.1', '0'),
#               ('19.RXA.2', '2'),
#               ('19.RXA.3', '20140520'),
#               ('19.RXA.4', '20140520'),
#               ('19.RXA.5',
#                OrderedDict([('19.RXA.5.0', '03'),
#                             ('19.RXA.5.1', 'MMR'),
#                             ('19.RXA.5.2', 'CVX')])),
#               ('19.RXA.6', '.5'),
#               ('19.RXA.7',
#                OrderedDict([('19.RXA.7.0', 'ML'), ('19.RXA.7.2', 'ISO+')])),
#               ('19.RXA.10',
#                OrderedDict([('19.RXA.10.0', '1234567891'),
#                             ('19.RXA.10.1', 'O=BRIAN'),
#                             ('19.RXA.10.2', 'ROBERT'),
#                             ('19.RXA.10.3', 'A'),
#                             ('19.RXA.10.5', 'DR'),
#                             ('19.RXA.10.6', 'MD')])),
#               ('19.RXA.11',
#                OrderedDict([('19.RXA.11.3', 'CHILD HEALTHCARE CLINIC'),
#                             ('19.RXA.11.8', '101 MAIN STREET'),
#                             ('19.RXA.11.10', 'BOSTON'),
#                             ('19.RXA.11.11', 'MA')])),
#               ('19.RXA.15', 'W2341234567'),
#               ('19.RXA.16', '20140630'),
#               ('19.RXA.17',
#                OrderedDict([('19.RXA.17.0', ' MSD'),
#                             ('19.RXA.17.1', ' MERCK'),
#                             ('19.RXA.17.2', 'MVX')]))]),
#  '20.RXR': OrderedDict([('20.RXR.0', 'RXR'),
#               ('20.RXR.1',
#                OrderedDict([('20.RXR.1.0', 'SC'),
#                             ('20.RXR.1.1', 'SUBCUTANEOUS'),
#                             ('20.RXR.1.2', 'HL70162')])),
#               ('20.RXR.2',
#                OrderedDict([('20.RXR.2.0', 'LA'),
#                             ('20.RXR.2.1', 'LEFT ARM'),
#                             ('20.RXR.2.2', 'HL70163')]))]),
#  '21.OBX': OrderedDict([('21.OBX.0', 'OBX'),
#               ('21.OBX.2', 'ST'),
#               ('21.OBX.3',
#                OrderedDict([('21.OBX.3.0', '60011-4'),
#                             ('21.OBX.3.1', 'VACCINATION ADVERSE EVENT'),
#                             ('21.OBX.3.2', 'LN')])),
#               ('21.OBX.5', 'ANAPHYLAXIS'),
#               ('21.OBX.11', 'F')]),
#  '22.NTE': OrderedDict([('22.NTE.0', 'NTE'),
#               ('22.NTE.3', 'VAERS FORM SUBMITTED BY PROVIDER')]),
#  '23.RXA': OrderedDict([('23.RXA.0', 'RXA'),
#               ('23.RXA.1', '0'),
#               ('23.RXA.2', '1'),
#               ('23.RXA.3', '20140415'),
#               ('23.RXA.4', '20140415'),
#               ('23.RXA.5',
#                OrderedDict([('23.RXA.5.0', '96'),
#                             ('23.RXA.5.1', 'TST-PPD INTRADERMAL'),
#                             ('23.RXA.5.2', 'CVX')])),
#               ('23.RXA.6', '5'),
#               ('23.RXA.7', 'TU')]),
#  '24.OBX': OrderedDict([('24.OBX.0', 'OBX'),
#               ('24.OBX.2', 'NM'),
#               ('24.OBX.3',
#                OrderedDict([('24.OBX.3.0', '1648-5'),
#                             ('24.OBX.3.1',
#                              'TUBERCULOSIS REACTION WHEAL 3D POST 5 TU ID'),
#                             ('24.OBX.3.2', 'LN')])),
#               ('24.OBX.5', '1'),
#               ('24.OBX.6', 'MM'),
#               ('24.OBX.8', 'N'),
#               ('24.OBX.11', 'F'),
#               ('24.OBX.14', '20140418')])}

# %%
json_dict["10.RXA"]
# Out:
# OrderedDict([('10.RXA.0', 'RXA'),
#              ('10.RXA.1', '0'),
#              ('10.RXA.2', '0'),
#              ('10.RXA.3', '20101207'),
#              ('10.RXA.4', '20101207'),
#              ('10.RXA.5',
#               OrderedDict([('10.RXA.5.0', '20'),
#                            ('10.RXA.5.1', 'TTP'),
#                            ('10.RXA.5.2', 'CVX')])),
#              ('10.RXA.6', '.5'),
#              ('10.RXA.7',
#               OrderedDict([('10.RXA.7.0', 'ML'), ('10.RXA.7.2', 'ISO+')])),
#              ('10.RXA.10',
#               OrderedDict([('10.RXA.10.0', '1234567891'),
#                            ('10.RXA.10.1', 'O=BRIAN'),
#                            ('10.RXA.10.2', 'ROBERT'),
#                            ('10.RXA.10.3', 'A'),
#                            ('10.RXA.10.5', 'DR'),
#                            ('10.RXA.10.6', ' MD')])),
#              ('10.RXA.11',
#               OrderedDict([('10.RXA.11.3', 'CHILD HEALTHCARE CLINIC'),
#                            ('10.RXA.11.8', '101 MAIN STREET'),
#                            ('10.RXA.11.10', 'London'),
#                            ('10.RXA.11.11', 'London')])),
#              ('10.RXA.15', 'W22532806'),
#              ('10.RXA.16', ' 20101230'),
#              ('10.RXA.17',
#               OrderedDict([('10.RXA.17.0', ' PMC'),
#                            ('10.RXA.17.1', ' PASTEUR MERIEUX CONNAUGHT'),
#                            ('10.RXA.17.2', 'MVX')])),
#              ('10.RXA.18',
#               OrderedDict([('10.RXA.18.0', '00'),
#                            ('10.RXA.18.1', 'PARENTAL DECISION'),
#                            ('10.RXA.18.2', 'NIP002')])),
#              ('10.RXA.20', 'RE')])

# %%
def parse_hl7(file_lines):
    delimiters = file_lines[0].split("|")[1]

    json_dict = dict()

    for i, line in enumerate(file_lines):
        #msh = line.split("|")[0]

        #Key for the message header will be the line number (i) \. the first field in the row
        #if less than 10, add padding so it can be sorted correctly
        if i < 10:
            msh = "0"+str(i) + "." + line.split("|")[0]
        else:
            msh = str(i) + "." + line.split("|")[0]

        json_dict[msh] = {}
        line = line.replace("\n", "")

        for ii, field in enumerate(line.split("|")):
            #construct key with MESSAGE HEADER.i.ii
            #key = line.split("|")[0]+"."+str(i)+"."+str(ii)
            #key = line.split("|")[0]+"."+str(ii)
            key = msh+"."+str(ii)


            # don't want the field if it is null
            if len(field)==0 or field=="":
                continue

            #dictionaries with nested keys/values need to be initialized before we can use them
            json_dict[msh][key] = {}

            for iii, segment in enumerate(field.split(delimiters[0])):
                #Construct a segment key with our previous key with an additional numeric value
                key_segment = key+"."+str(iii)

                #don't want the field if it is null
                if len(segment)==0 or segment=="":
                    continue

                #dictionaries with nested keys/values need to be initialized before we can use them
                json_dict[msh][key][key_segment] = {}

                for iiii, component in enumerate(segment.split(delimiters[1])):
                    #construct a key for our compoments
                    key_component = key_segment+"."+str(iiii)

                    """ inject the values by assigning the most inner values first then going outwards """

                    #only need to assign the inner dictionary value if it exists 
                    #(if we split on the delimiter and more than one value exists)
                    if len(segment.split("~")) > 1: 

                        #don't want the field if it is null
                        if len(component)==0 or component=="":
                            continue
                        json_dict[msh][key][key_segment][key_component] = component
                    elif len(field.split("^")) > 1:

                         #don't want the field if it is null
                        if len(segment)==0 or segment=="":
                            continue
                        json_dict[msh][key][key_segment] = segment
                    else:

                         #don't want the field if it is null
                        if len(segment)==0 or segment=="":
                            continue
                        json_dict[msh][key] = field

    return json_dict

# %%
import json
json.dumps(parse_hl7(obs))
# Out:
# '{"00.MSH": {"00.MSH.0": "MSH", "00.MSH.1": {"00.MSH.1.1": {"00.MSH.1.1.1": "\\\\&"}}, "00.MSH.2": "HL7Soup", "00.MSH.3": "Instance1", "00.MSH.4": "HL7Soup", "00.MSH.5": "Instance2", "00.MSH.6": "201005221610", "00.MSH.8": {"00.MSH.8.0": "VXR", "00.MSH.8.1": "V03"}, "00.MSH.9": "20100522MA53", "00.MSH.10": "T", "00.MSH.11": "2.5.1", "00.MSH.14": "AL"}, "01.MSA": {"01.MSA.0": "MSA", "01.MSA.1": "AA", "01.MSA.2": "20100522GA40"}, "02.QRD": {"02.QRD.0": "QRD", "02.QRD.1": "201405221605", "02.QRD.2": "R", "02.QRD.3": "I", "02.QRD.4": "20100522GA05", "02.QRD.7": {"02.QRD.7.0": "30", "02.QRD.7.1": "RD"}, "02.QRD.8": {"02.QRD.8.0": "3245", "02.QRD.8.1": "Martins", "02.QRD.8.2": "Jim", "02.QRD.8.3": "Christoper"}, "02.QRD.9": "VXI", "02.QRD.10": {"02.QRD.10.1": "MSIPP"}}, "03.QRF": {"03.QRF.0": "QRF", "03.QRF.1": "MR0000", "03.QRF.5": {"03.QRF.5.0": {"03.QRF.5.0.0": "256946789", "03.QRF.5.0.1": "20100607", "03.QRF.5.0.2": "MA", "03.QRF.5.0.3": "MA99999999", "03.QRF.5.0.4": "88888888", "03.QRF.5.0.5": "Martins"}, "03.QRF.5.1": "Natalie", "03.QRF.5.2": {"03.QRF.5.2.0": "Lynn", "03.QRF.5.2.1": "Randle", "03.QRF.5.2.2": "4466725", "03.QRF.5.2.3": "Martins"}, "03.QRF.5.3": "Jim", "03.QRF.5.4": {"03.QRF.5.4.0": "Christopher", "03.QRF.5.4.1": "446618"}}}, "04.PID": {"04.PID.0": "PID", "04.PID.2": "87687", "04.PID.3": {"04.PID.3.0": "1234", "04.PID.3.4": "SR", "04.PID.3.5": {"04.PID.3.5.1": "1234-12"}, "04.PID.3.9": "LR", "04.PID.3.10": {"04.PID.3.10.1": "3872"}, "04.PID.3.14": {"04.PID.3.14.0": "MR", "04.PID.3.14.1": "221323671"}, "04.PID.3.18": "SS", "04.PID.3.19": {"04.PID.3.19.1": "430078856"}, "04.PID.3.23": "MA", "04.PID.3.24": " "}, "04.PID.5": {"04.PID.5.0": "Martins", "04.PID.5.1": "Jim", "04.PID.5.2": "Christopher", "04.PID.5.6": "L"}, "04.PID.6": {"04.PID.6.0": "Randle", "04.PID.6.6": "M"}, "04.PID.7": "20100607", "04.PID.8": "M", "04.PID.9": {"04.PID.9.0": "Martins", "04.PID.9.1": "BABY BOY", "04.PID.9.7": " B"}, "04.PID.10": {"04.PID.10.0": "W", "04.PID.10.1": "WHITE", "04.PID.10.2": "NY8 RACE CODES", "04.PID.10.3": "W", "04.PID.10.4": "WHITE", "04.PID.10.5": "HL70005"}, "04.PID.11": {"04.PID.11.0": "123 HIgh St", "04.PID.11.1": "APT 3B", "04.PID.11.2": "London", "04.PID.11.3": "London", "04.PID.11.4": "EY2 5EE", "04.PID.11.5": " ", "04.PID.11.6": "M", "04.PID.11.7": "MSA CODE", "04.PID.11.8": {"04.PID.11.8.0": "MA034", "04.PID.11.8.1": "345 ELM ST"}, "04.PID.11.10": "London", "04.PID.11.11": "London", "04.PID.11.12": "NH3 7TY", "04.PID.11.14": {"04.PID.11.14.0": "Building"}, "04.PID.11.20": "BR", "04.PID.11.22": "MA002"}, "04.PID.12": " ", "04.PID.13": {"04.PID.13.0": "(617) 555-1212 ", "04.PID.13.1": "PRN", "04.PID.13.2": "PH", "04.PID.13.5": "617", "04.PID.13.6": "5551212"}, "04.PID.15": {"04.PID.15.0": "EN", "04.PID.15.1": "ENGLISH", "04.PID.15.2": "HL70296"}, "04.PID.23": "CHILDRENS HOSPITAL"}, "05.PD1": {"05.PD1.0": "PD1", "05.PD1.3": {"05.PD1.3.0": "CHILDREN=S HOSPITAL", "05.PD1.3.1": "L", "05.PD1.3.2": "1234", "05.PD1.3.6": {"05.PD1.3.6.0": "XX", "05.PD1.3.6.1": "LEXINGTON CLINIC"}, "05.PD1.3.8": "1234A", "05.PD1.3.12": "FI "}, "05.PD1.4": {"05.PD1.4.0": "12345", "05.PD1.4.1": "CARE", "05.PD1.4.2": " PRIMARY", "05.PD1.4.5": "DR", "05.PD1.4.6": "MD", "05.PD1.4.9": "L", "05.PD1.4.12": "DN"}, "05.PD1.11": {"05.PD1.11.0": "03", "05.PD1.11.1": "REMINDER/RECALL - NO CALLS", "05.PD1.11.2": "HL70215"}, "05.PD1.12": "Y", "05.PD1.13": "A", "05.PD1.14": "20100607"}, "06.NK1": {"06.NK1.0": "NK1", "06.NK1.1": "1", "06.NK1.2": {"06.NK1.2.0": "Martins", "06.NK1.2.1": "Natalie", "06.NK1.2.2": "Lynn"}, "06.NK1.3": {"06.NK1.3.0": "32", "06.NK1.3.1": "MOTHER", "06.NK1.3.2": "HL70063"}, "06.NK1.33": {"06.NK1.33.0": "898666725", "06.NK1.33.4": "SS"}}, "07.NK1": {"07.NK1.0": "NK1", "07.NK1.1": "2", "07.NK1.2": {"07.NK1.2.0": "Martins", "07.NK1.2.1": "John", "07.NK1.2.2": "Andrew"}, "07.NK1.3": {"07.NK1.3.0": "33", "07.NK1.3.1": "FATHER", "07.NK1.3.2": "HL70063"}, "07.NK1.33": {"07.NK1.33.0": "822546618", "07.NK1.33.4": "SS"}}, "08.PV1": {"08.P ...

# %%
def addKeys (listOfKeys):
    if len(listOfKeys)==1:
        print("returning last element")
        return listOfKeys
    else:
        print("calling add keys with these values: " + str(listOfKeys[:-1]))
        return addKeys(listOfKeys[:-1])

# %%
print(addKeys([("a",1),("b",2)]))
# Out:
# calling add keys with these values: [('a', 1)]
# returning last element
# [('a', 1)]

# %%
[1,2,3][:-1]
# Out:
# [1, 2]

# %%
def nested_pairs2dict(pairs):
    d = {}
    for k, v in pairs:
        if isinstance(v, list): # assumes v is also list of pairs
           v = nested_pairs2dict(v)
        d[k] = v
    return d

# %%
nested_pairs2dict([("a",[("aa", 1)]),("b",2)])
# Out:
# {'a': {'aa': 1}, 'b': 2}

# %%
for k, v, in [("a",[("aa", 1)]),("b",2)]:
    if isinstance(v, list):
        print(k, v)
# Out:
# a [('aa', 1)]
